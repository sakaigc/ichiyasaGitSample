# %% [markdown]
# <a href="https://colab.research.google.com/github/sakaigc/ichiyasaGitSample/blob/main/section_1/01_chat_gpt_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ChatGPT APIを使ってみよう！
#
# ChatGPT APIを体験します。
# API keyを設定し、Chat GPT APIからのレスポンスを取得してみましょう。
# なお、APIの利用は有料になりますので、決済手段の登録が必要になります。.
# 決済手段を登録しないままコードを実行するとエラーになります。

# %% [markdown]
# ## ライブラリのインストール
# ChatGPT APIを使用するために必要なライブラリ、openaiをインストールします。

# %%
# !pip install "openai<1.0.0"
# Out:
# Collecting openai<1.0.0
#   Downloading openai-0.28.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from openai<1.0.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai<1.0.0) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from openai<1.0.0) (3.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai<1.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai<1.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai<1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai<1.0.0) (2025.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai<1.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai<1.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai<1.0.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai<1.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai<1.0.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai<1.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai<1.0.0) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->openai<1.0.0) (4.15.0)
# Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.12.0
#     Uninstalling openai-2.12.0:
#       Successfully uninstalled openai-2.12.0
# Successfully installed openai-0.28.1

# %% [markdown]
# インストールの完了後、openaiをインポートしておきます。

# %%
import openai

# %% [markdown]
# ## API Keyの設定
# ChatGPT APIを使用するために必要な「API key」を設定します。
# 以下のコードの、
# `openai.api_key = "Your API key"`
# における
# `Your API key`の箇所を、自分のAPI keyに置き換えます。
# ChatGPTのAPI keyは、OpenAIのサイトで取得できます。
# https://platform.openai.com/account/api-keys

# %%
openai.api_key = "Your API key"

# %% [markdown]
# API keyの流出にはリスクがあります。
# 他者に知られないように、慎重に扱ってください。

# %% [markdown]
# ## レスポンスの取得
# `openai.ChatCompletion.create()`により、ChatGPT APIからのレスポンスを取得します。
# その際に、モデルを指定してメッセージを送ります。

# %%
# ChatGPT APIからのレスポンスを取得する
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "あなたは優秀なアシスタントAIです。"},
        {"role": "user", "content":"あなたはどんなことができますか？"}
        ]
)

# レスポンスの表示
print(response['choices'][0]['message']['content'])

# %% [markdown]
# ChatGPT APIからのレスポンスを取得することができました。
#
# 上記のコードの実行後、OpenAIのサイトでAPIの使用量を確認してみましょう。
# https://platform.openai.com/account/usage
